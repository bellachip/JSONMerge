# %%
# import csv
import json

# %%
stack = []
filedate = "20181015"
def readfile(file, str=""):
    with open(file, 'r') as r:
        for lines in r:
            str = json.loads(lines)
            stack.append(str)

    # print(data)
    return stack

# %%
def extract_values(obj, key):
    # """Pull all values of specified key from nested JSON."""
    arr = []

    def extract(obj, arr, key):
        # """Recursively search for values of key in JSON tree."""
        if isinstance(obj, dict):
            for k, v in obj.items():
                if isinstance(v, (dict, list)):
                    extract(v, arr, key)
                elif k == key:
                    arr.append(v)
        elif isinstance(obj, list):
            for item in obj:
                extract(item, arr, key)
        return arr

    results = extract(obj, arr, key)
    return results

# %%
def ignore_cursor_getall_nodes_responses(json_data):

    j=0
    arr = []
    # print(len(json_data))
    # print(len(json_data[0]['response']))
    # print(len(json_data[1]['response']))
    # print(len(json_data[2]['response']))
    # print(len(json_data[3]['response']))
    for i in  range(len(json_data)): #4

        for j in range(len(json_data[i]['response'])):
            arr.append(json_data[i]['response'][j])


    return arr #returns array for array with all nodes
    # print(len(arr))

# %%
def id_checker(id, array2):
    if id in array2:
        return True
    else:
        return False

# %%
def check_for_duplicate(array_nodes_one , array_nodes_two):
    # if len(array_nodes_one) < len(array_nodes_two):
    #     print("hello")
    array_of_id_two = []

    for i in range(len(array_nodes_two)):
        array_of_id_two.append(array_nodes_two[i]['id'])

    print(array_of_id_two)

    print(array_nodes_one[1]['id'])
    for i in range(len(array_nodes_one)):
        array_node_id = array_nodes_one[i]['id']
        if id_checker(array_node_id, array_of_id_two):
            return array_node_id

# %%
def dubplicate_id_handler(array_nodes_one, array_nodes_two):

    if check_for_

# %%
def main():

    json_data_one = readfile("data/6971761113_20181015141058.txt")
    json_data_two = readfile("data/6971761113_20181015144051.txt")
    array_nodes_one = ignore_cursor_getall_nodes_responses(json_data_one)
    array_nodes_two = ignore_cursor_getall_nodes_responses(json_data_two)
    is_check = check_for_duplicate(array_nodes_one , array_nodes_two)
    print(is_check)



main()

# %%
readfile("data/6971761113_20181015141058.txt")
# Out:
# [{'cursor': {'prev': None,
#    'hasNext': True,
#    'next': '1539611158465541:0:0',
#    'hasPrev': False,
#    'total': None,
#    'id': '1539611158465541:0:0',
#    'more': True},
#   'code': 0,
#   'response': [{'editableUntil': '2018-10-22T18:01:22',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>You can read? aw shucks.</p>',
#     'id': '4146297139',
#     'createdAt': '2018-10-15T18:01:22',
#     'author': {'username': 'carriebarber',
#      'about': '',
#      'name': 'Carrie Barber',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2013-07-05T15:34:46',
#      'profileUrl': 'https://disqus.com/by/carriebarber/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '60816887',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/carriebarber.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/6081/6887/avatar32.jpg?1485236270'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/carriebarber.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/6081/6887/avatar92.jpg?1485236270',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/carriebarber.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/6081/6887/avatar92.jpg?1485236270'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146150478,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'You can read? aw shucks.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:57:07',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>You are an idiot trumper. You adore a traitor. Over 30 indictments, 5 guilty pleas and an administration consisting of Sessions, Manafort, Flynn, Papadopoulos, Gates, Donnie jr and Kushner who all lied under oath to the FBI and congress about meeting with Russia. Idiot traitorous trumper.</p>',
#     'id': '4146289447',
#     'createdAt': '2018-10-15T17:57:07',
#     'author': {'username': 'rolandwelsh',
#      'about': '',
#      'name': 'Roland Welsh',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2016-10-15T02:04:05',
#      'profileUrl': 'https://disqus.com/by/rolandwelsh/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '226560595',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar32.jpg?1539626228'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145902797,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'You are an idiot trumper. You adore a traitor. Over 30 indictments, 5 guilty pleas and an administration consisting of Sessions, Manafort, Flynn, Papadopoulos, Gates, Donnie jr and Kushner who all lied under oath to the FBI and congress about meeting with Russia. Idiot traitorous trumper.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:53:20',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>In the current news cycle Kavanaugh is on the brink of forgot.</p>',
#     'id': '4146282637',
#     'createdAt': '2018-10-15T17:53:20',
#     'author': {'username': 'disqus_EUXVGAPAat',
#      'about': '',
#      'name': 'Ronny',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2016-12-16T20:54:19',
#      'profileUrl': 'https://disqus.com/by/disqus_EUXVGAPAat/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '235347406',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/disqus_EUXVGAPAat.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/23534/7406/avatar32.jpg?1539007654'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/disqus_EUXVGAPAat.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/23534/7406/avatar92.jpg?1539007654',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/disqus_EUXVGAPAat.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/23534/7406/avatar92.jpg?1539007654'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146223150,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'In the current news cycle Kavanaugh is on the brink of forgot.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:50:21',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>Hey ignoramus. You're a liar and an idiot. Anyone following the market after republicans destroyed it knows the growth Obama created, even after 500 filibusters against him. As McConnell first stated, their job was to make Obama a one term president, instead of building the country. Typical putin loving trump idiot. Traitorous moron.</p>",
#     'id': '4146277435',
#     'createdAt': '2018-10-15T17:50:21',
#     'author': {'username': 'rolandwelsh',
#      'about': '',
#      'name': 'Roland Welsh',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2016-10-15T02:04:05',
#      'profileUrl': 'https://disqus.com/by/rolandwelsh/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '226560595',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar32.jpg?1539626228'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145905040,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "Hey ignoramus. You're a liar and an idiot. Anyone following the market after republicans destroyed it knows the growth Obama created, even after 500 filibusters against him. As McConnell first stated, their job was to make Obama a one term president, instead of building the country. Typical putin loving trump idiot. Traitorous moron.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:43:47',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Typical lying trumptrash. You idiots lie through your yellow rotting <a href="http://disq.us/url?url=http%3A%2F%2Fteeth.like%3AYfpGFHhnEB2bUF3_V0SQsraiDZQ&amp;cuid=1212423" rel="nofollow noopener" title="teeth.like">teeth.like</a> your traitorous idiot in chief. 1.8 represents the IQ  of the average idiot lying trumper.</p>',
#     'id': '4146265724',
#     'createdAt': '2018-10-15T17:43:47',
#     'author': {'username': 'rolandwelsh',
#      'about': '',
#      'name': 'Roland Welsh',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2016-10-15T02:04:05',
#      'profileUrl': 'https://disqus.com/by/rolandwelsh/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '226560595',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar32.jpg?1539626228'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145841325,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Typical lying trumptrash. You idiots lie through your yellow rotting teeth.like your traitorous idiot in chief. 1.8 represents the IQ  of the average idiot lying trumper.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': ['links'],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:40:56',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 1,
#     'message': "<p>The ignoramus in chief is going to see something big happen real soon and that's a blue wave that will kick his rotting traitorous carcass. Ever see those morons flashing signs that read drain the swamp at his rallies? Stupidest bunch of dopes to ever crawl out of the mud.</p>",
#     'id': '4146260717',
#     'createdAt': '2018-10-15T17:40:56',
#     'author': {'username': 'rolandwelsh',
#      'about': '',
#      'name': 'Roland Welsh',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2016-10-15T02:04:05',
#      'profileUrl': 'https://disqus.com/by/rolandwelsh/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '226560595',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar32.jpg?1539626228'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/rolandwelsh.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/22656/595/avatar92.jpg?1539626228'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "The ignoramus in chief is going to see something big happen real soon and that's a blue wave that will kick his rotting traitorous carcass. Ever see those morons flashing signs that read drain the swamp at his rallies? Stupidest bunch of dopes to ever crawl out of the mud.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 1,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:37:31',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Prove it then.</p>',
#     'id': '4146254552',
#     'createdAt': '2018-10-15T17:37:31',
#     'author': {'username': 'disqus_1I9IGnAm6p',
#      'about': '',
#      'name': 'The Truth About Trump',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2015-05-23T17:09:55',
#      'profileUrl': 'https://disqus.com/by/disqus_1I9IGnAm6p/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '158792147',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/disqus_1I9IGnAm6p.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/15879/2147/avatar32.jpg?1497020384'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/disqus_1I9IGnAm6p.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/15879/2147/avatar92.jpg?1497020384',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/disqus_1I9IGnAm6p.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/15879/2147/avatar92.jpg?1497020384'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146189893,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Prove it then.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:33:18',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>He is "Ametican" and is a "religious leader".</p><p>Why did you mention prison? I didn\'t mention prison. I just said he was released from Turkey. Isn\'t that a good thing?</p>',
#     'id': '4146247051',
#     'createdAt': '2018-10-15T17:33:18',
#     'author': {'username': 'skippy3504',
#      'about': '',
#      'name': 'Skippy3504',
#      'disable3rdPartyTrackers': True,
#      'isPowerContributor': False,
#      'joinedAt': '2014-12-02T11:53:46',
#      'profileUrl': 'https://disqus.com/by/skippy3504/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '134156073',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/skippy3504.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/13415/6073/avatar32.jpg?1438082458'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/skippy3504.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/13415/6073/avatar92.jpg?1438082458',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/skippy3504.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/13415/6073/avatar92.jpg?1438082458'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146128229,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'He is "Ametican" and is a "religious leader". \n\nWhy did you mention prison? I didn\'t mention prison. I just said he was released from Turkey. Isn\'t that a good thing?',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': True,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:30:54',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>That's not accomplishments...that's filling federal vacancies held open by Republicans...wooo...that was hard...</p>",
#     'id': '4146242717',
#     'createdAt': '2018-10-15T17:30:54',
#     'author': {'username': 'disqus_3L5QYI0WKm',
#      'about': '',
#      'name': 'Question Everything',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-03-27T13:14:37',
#      'profileUrl': 'https://disqus.com/by/disqus_3L5QYI0WKm/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '100651363',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/disqus_3L5QYI0WKm.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/10065/1363/avatar32.jpg?1528414031'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/disqus_3L5QYI0WKm.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/10065/1363/avatar92.jpg?1528414031',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/disqus_3L5QYI0WKm.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/10065/1363/avatar92.jpg?1528414031'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145828720,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "That's not accomplishments...that's filling federal vacancies held open by Republicans...wooo...that was hard...",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:27:48',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>"After all, it\'s all about aMErica!"</p>',
#     'id': '4146237172',
#     'createdAt': '2018-10-15T17:27:48',
#     'author': {'username': 'disqus_GQEXyBu6S6',
#      'about': '',
#      'name': 'Cicero',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-02-21T01:00:06',
#      'profileUrl': 'https://disqus.com/by/disqus_GQEXyBu6S6/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '243005859',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': '"After all, it\'s all about aMErica!"',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:26:49',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Let me correct your attempt at correcting me. First of, it was a consulate, not the embassy.</p><p>Please search "Russian Seattle consulate" and March 26, 2018. There are numerous stories that support my previous post.</p>',
#     'id': '4146235444',
#     'createdAt': '2018-10-15T17:26:49',
#     'author': {'username': 'skippy3504',
#      'about': '',
#      'name': 'Skippy3504',
#      'disable3rdPartyTrackers': True,
#      'isPowerContributor': False,
#      'joinedAt': '2014-12-02T11:53:46',
#      'profileUrl': 'https://disqus.com/by/skippy3504/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '134156073',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/skippy3504.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/13415/6073/avatar32.jpg?1438082458'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/skippy3504.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/13415/6073/avatar92.jpg?1438082458',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/skippy3504.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/13415/6073/avatar92.jpg?1438082458'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146162288,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Let me correct your attempt at correcting me. First of, it was a consulate, not the embassy. \n\nPlease search "Russian Seattle consulate" and March 26, 2018. There are numerous stories that support my previous post.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:19:53',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>The Dems believed in May that they could win the House if they could win six or seven seats in CA by winning the following congressional districts (CA10, CA21, CA25, CA39, CA45, CA48, and CA49).  That would turn the CA congressional delegation from 53-14 Dem to 60-7 Dem.  It was not happening before the Kavanaugh hearing.  Berkeley/IGS dropped polls last week on CD’s 10, 21, 25, 39, 45, 48, and 49; but the sampling was done from 9/16-9/23 or before the Kavanaugh fiasco.  All the polls on RCP in these potential swing districts  polls were sampled in September and also prior to the Kavanaugh confirmation hearings.  Here are the September results.  CD10 pre-Kavanaugh has Dem up +5; CD21 pre-Kavanaugh has the Rep+11; CD22 pre-Kavanaugh has two polls that average R+11; CD25 has two polls (B/IGS D+4 and NYT R+2) that have the Dems+1; CD39 has two polls that average R+4.5; CD45 has two polls that average D+6; CD48 has two polls that show a tie; CD49 has two polls that average D+12; CD50 has two polls that have the Rep+8.5.  Based on polls pre-Kavanaugh, CA21 and CA39 are likely to go Rep.  CD25 and CD48 are tied.  CD10 (D+5) and CD45 (D+6) should swing Rep if any polling is done in the next week or post Kavanaugh.  Only CD49 looks like a Dem win in the 7 seats the Dems targeted last May before the CA primaries in June.  RCP calls five of them toss-ups (CA10, CA25, CA39, CA45, and CA48).  Post-Kavanaugh polling should show a weakening in the Dems vote in those five.  Without CA, there is no blue wave.</p>',
#     'id': '4146223150',
#     'createdAt': '2018-10-15T17:19:53',
#     'author': {'username': 'Ran72ger',
#      'about': '',
#      'name': 'Ran72ger',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-09-20T20:47:59',
#      'profileUrl': 'https://disqus.com/by/Ran72ger/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '265797872',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'The Dems believed in May that they could win the House if they could win six or seven seats in CA by winning the following congressional districts (CA10, CA21, CA25, CA39, CA45, CA48, and CA49).  That would turn the CA congressional delegation from 53-14 Dem to 60-7 Dem.  It was not happening before the Kavanaugh hearing.  Berkeley/IGS dropped polls last week on CD’s 10, 21, 25, 39, 45, 48, and 49; but the sampling was done from 9/16-9/23 or before the Kavanaugh fiasco.  All the polls on RCP in these potential swing districts  polls were sampled in September and also prior to the Kavanaugh confirmation hearings.  Here are the September results.  CD10 pre-Kavanaugh has Dem up +5; CD21 pre-Kavanaugh has the Rep+11; CD22 pre-Kavanaugh has two polls that average R+11; CD25 has two polls (B/IGS D+4 and NYT R+2) that have the Dems+1; CD39 has two polls that average R+4.5; CD45 has two polls that average D+6; CD48 has two polls that show a tie; CD49 has two polls that average D+12; CD50 has two polls that have the Rep+8.5.  Based on polls pre-Kavanaugh, CA21 and CA39 are likely to go Rep.  CD25 and CD48 are tied.  CD10 (D+5) and CD45 (D+6) should swing Rep if any polling is done in the next week or post Kavanaugh.  Only CD49 looks like a Dem win in the 7 seats the Dems targeted last May before the CA primaries in June.  RCP calls five of them toss-ups (CA10, CA25, CA39, CA45, and CA48).  Post-Kavanaugh polling should show a weakening in the Dems vote in those five.  Without CA, there is no blue wave.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:15:54',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>And you go on to prove what you are.  Hate filled AND small minded.</p>',
#     'id': '4146216185',
#     'createdAt': '2018-10-15T17:15:54',
#     'author': {'username': 'durwood_mcelroy',
#      'about': '',
#      'name': 'Durwood McElroy',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2018-09-10T10:17:07',
#      'profileUrl': 'https://disqus.com/by/durwood_mcelroy/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '297443207',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146194283,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'And you go on to prove what you are.  Hate filled AND small minded.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:09:58',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>If the house does turn, we will likely not see anything getting done other than must pass bills, like spending. Something along the lines of congress starting in 2010. It is not like they are getting a lot done now though really. Well other than appointments, which unless the democrats take the senate will keep rolling along.</p>',
#     'id': '4146202920',
#     'createdAt': '2018-10-15T17:09:58',
#     'author': {'username': 'conservatl',
#      'about': '',
#      'name': 'conservatl',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2011-01-26T20:41:26',
#      'profileUrl': 'https://disqus.com/by/conservatl/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '6685933',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146092056,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'If the house does turn, we will likely not see anything getting done other than must pass bills, like spending. Something along the lines of congress starting in 2010. It is not like they are getting a lot done now though really. Well other than appointments, which unless the democrats take the senate will keep rolling along.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:05:32',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Yawn. GFY</p>',
#     'id': '4146194283',
#     'createdAt': '2018-10-15T17:05:32',
#     'author': {'username': 'mydogplayspedalsteel',
#      'about': '',
#      'name': 'my dog plays pedal steel',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2018-03-26T16:12:26',
#      'profileUrl': 'https://disqus.com/by/mydogplayspedalsteel/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '283788866',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/mydogplayspedalsteel.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/28378/8866/avatar32.jpg?1522173225'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/mydogplayspedalsteel.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/28378/8866/avatar92.jpg?1522173225',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/mydogplayspedalsteel.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/28378/8866/avatar92.jpg?1522173225'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146179881,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Yawn. GFY',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:04:59',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>Not sure where this article was going, it wants to dispute the numbers inside, saying there are usually a few empty seats. But then doesn't hide the fact there are crowds outside. If you are going to a presidential event, you are going to be screened, and that takes time. As I recall the president attend the national championship game last January. People were arriving 6 hours and more early to get there and still were not getting inside until way after the start.</p>",
#     'id': '4146192673',
#     'createdAt': '2018-10-15T17:04:59',
#     'author': {'username': 'conservatl',
#      'about': '',
#      'name': 'conservatl',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2011-01-26T20:41:26',
#      'profileUrl': 'https://disqus.com/by/conservatl/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '6685933',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "Not sure where this article was going, it wants to dispute the numbers inside, saying there are usually a few empty seats. But then doesn't hide the fact there are crowds outside. If you are going to a presidential event, you are going to be screened, and that takes time. As I recall the president attend the national championship game last January. People were arriving 6 hours and more early to get there and still were not getting inside until way after the start.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:04:06',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>No need to swear... it's a cold hard fact.</p>",
#     'id': '4146189893',
#     'createdAt': '2018-10-15T17:04:06',
#     'author': {'username': 'brennanbeckenbauer',
#      'about': "Henry Cavill's a great choice.",
#      'name': 'Geralt of Rivia',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-12-17T23:51:53',
#      'profileUrl': 'https://disqus.com/by/brennanbeckenbauer/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '274410179',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/brennanbeckenbauer.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/27441/179/avatar32.jpg?1516121801'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/brennanbeckenbauer.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/27441/179/avatar92.jpg?1516121801',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/brennanbeckenbauer.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/27441/179/avatar92.jpg?1516121801'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145776860,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "No need to swear... it's a cold hard fact.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T17:00:59',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>Thank you Rick..  It's people like who keep the Republicans in power.  HAHAHA!!.</p>",
#     'id': '4146184536',
#     'createdAt': '2018-10-15T17:00:59',
#     'author': {'username': 'charleslabry',
#      'about': '',
#      'name': 'Charles Labry',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-07-09T16:33:15',
#      'profileUrl': 'https://disqus.com/by/charleslabry/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '113739435',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar32.jpg?1472045849'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146027384,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "Thank you Rick..  It's people like who keep the Republicans in power.  HAHAHA!!.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:58:20',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>When in a hate hole, stop digging.  You are a brainwashed, mate mongering hater.  You parent's are a disgrace to this world and every teacher you've ever had failed you, miserable.  You sound just like your socialist boy, Hitler.</p>",
#     'id': '4146179881',
#     'createdAt': '2018-10-15T16:58:20',
#     'author': {'username': 'durwood_mcelroy',
#      'about': '',
#      'name': 'Durwood McElroy',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2018-09-10T10:17:07',
#      'profileUrl': 'https://disqus.com/by/durwood_mcelroy/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '297443207',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146165664,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "When in a hate hole, stop digging.  You are a brainwashed, mate mongering hater.  You parent's are a disgrace to this world and every teacher you've ever had failed you, miserable.  You sound just like your socialist boy, Hitler.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:53:15',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>So  you really are a hate mongering bigot???  I thought so.</p>',
#     'id': '4146170681',
#     'createdAt': '2018-10-15T16:53:15',
#     'author': {'username': 'charleslabry',
#      'about': '',
#      'name': 'Charles Labry',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-07-09T16:33:15',
#      'profileUrl': 'https://disqus.com/by/charleslabry/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '113739435',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar32.jpg?1472045849'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146165664,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'So  you really are a hate mongering bigot???  I thought so.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': True,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:52:15',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Are all of your comments as ignorant  as this one???</p>',
#     'id': '4146168954',
#     'createdAt': '2018-10-15T16:52:15',
#     'author': {'username': 'charleslabry',
#      'about': '',
#      'name': 'Charles Labry',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-07-09T16:33:15',
#      'profileUrl': 'https://disqus.com/by/charleslabry/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '113739435',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar32.jpg?1472045849'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146148535,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Are all of your comments as ignorant  as this one???',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:50:52',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Sorry Snowflakes.   The GOP wins big in November.  They will win more seats in the House and Senate.</p>',
#     'id': '4146166525',
#     'createdAt': '2018-10-15T16:50:52',
#     'author': {'username': 'charleslabry',
#      'about': '',
#      'name': 'Charles Labry',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-07-09T16:33:15',
#      'profileUrl': 'https://disqus.com/by/charleslabry/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '113739435',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar32.jpg?1472045849'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/charleslabry.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/11373/9435/avatar92.jpg?1472045849'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Sorry Snowflakes.   The GOP wins big in November.  They will win more seats in the House and Senate.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:50:24',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': "<p>If it was up to me, we'd round you all up and kick your @ss out</p>",
#     'id': '4146165664',
#     'createdAt': '2018-10-15T16:50:24',
#     'author': {'username': 'mydogplayspedalsteel',
#      'about': '',
#      'name': 'my dog plays pedal steel',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2018-03-26T16:12:26',
#      'profileUrl': 'https://disqus.com/by/mydogplayspedalsteel/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '283788866',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/mydogplayspedalsteel.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/28378/8866/avatar32.jpg?1522173225'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/mydogplayspedalsteel.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/28378/8866/avatar92.jpg?1522173225',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/mydogplayspedalsteel.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/28378/8866/avatar92.jpg?1522173225'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146158116,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "If it was up to me, we'd round you all up and kick your @ss out",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:48:29',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 0,
#     'message': '<p>Wrong,  Let me correct you.  The Russian embassy is (was) located in San Francisco, NOT  Seattle.<br>And why do religious leaders keep going to NK?  Then getting themselves locked up.</p>',
#     'id': '4146162288',
#     'createdAt': '2018-10-15T16:48:29',
#     'author': {'username': 'AdmiralJ',
#      'about': '',
#      'name': 'AdmiralJ',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2009-07-17T21:10:18',
#      'profileUrl': 'https://disqus.com/by/AdmiralJ/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '500500',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/AdmiralJ.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/50/500/avatar32.jpg?1409789408'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/AdmiralJ.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/50/500/avatar92.jpg?1409789408',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/AdmiralJ.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/50/500/avatar92.jpg?1409789408'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4146018107,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Wrong,  Let me correct you.  The Russian embassy is (was) located in San Francisco, NOT  Seattle.\nAnd why do religious leaders keep going to NK?  Then getting themselves locked up.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T16:46:06',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 1,
# ...
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Scream at the sky 2.0. Wonder what the title of the book for why liberals lost will be.\n\n\nWhat Happened 3: Lost in Outer Space',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': -1,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:48:56',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 4,
#     'message': '<p>Pallets of Kleenex for the Mookie machine...</p>',
#     'id': '4145770659',
#     'createdAt': '2018-10-15T12:48:56',
#     'author': {'username': 'disqus_UIk6AiWFjs',
#      'about': 'I have zero tolerance for people who get paid to lie.',
#      'name': 'Trump Rules',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2018-07-21T20:31:47',
#      'profileUrl': 'https://disqus.com/by/disqus_UIk6AiWFjs/',
#      'url': '',
#      'location': "Nebraska.  The Solid Core of our Nation's Defense Infrastructure Against Russia.",
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '292715519',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/disqus_UIk6AiWFjs.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/29271/5519/avatar32.jpg?1536431752'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/disqus_UIk6AiWFjs.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/29271/5519/avatar92.jpg?1536431752',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/disqus_UIk6AiWFjs.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/29271/5519/avatar92.jpg?1536431752'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145768916,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Pallets of Kleenex for the Mookie machine...',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 4,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:48:41',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 3,
#     'message': '<p>He said ironically as Nazis beat someone up in NYC, a GOP candidate in PA said he\'d stomp on his opponents face and the president routinely leads "lock her up" chants</p>',
#     'id': '4145770342',
#     'createdAt': '2018-10-15T12:48:41',
#     'author': {'username': 'disqus_59PrUrHVI6',
#      'about': '',
#      'name': 'idkmybffjill',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-10-27T16:50:28',
#      'profileUrl': 'https://disqus.com/by/disqus_59PrUrHVI6/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '269434744',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145768916,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'He said ironically as Nazis beat someone up in NYC, a GOP candidate in PA said he\'d stomp on his opponents face and the president routinely leads "lock her up" chants',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 3,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:48:18',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 4,
#     'message': '<p>That’s just stupid</p>',
#     'id': '4145769821',
#     'createdAt': '2018-10-15T12:48:18',
#     'author': {'username': 'ke0vin',
#      'about': '',
#      'name': 'ke0vin',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-03-16T13:54:02',
#      'profileUrl': 'https://disqus.com/by/ke0vin/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '245704929',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/ke0vin.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/24570/4929/avatar32.jpg?1507053264'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/ke0vin.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/24570/4929/avatar92.jpg?1507053264',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/ke0vin.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/24570/4929/avatar92.jpg?1507053264'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145768916,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'That’s just stupid',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 4,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:48:15',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 22,
#     'message': '<p>Trump: It’s all about me, and always has been.</p>',
#     'id': '4145769772',
#     'createdAt': '2018-10-15T12:48:15',
#     'author': {'username': '40words',
#      'about': '',
#      'name': '40words',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2012-08-03T13:23:55',
#      'profileUrl': 'https://disqus.com/by/40words/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '30008336',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Trump: It’s all about me, and always has been.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 22,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:48:09',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 2,
#     'message': '<p>Why are Cons addicted to PROJECTION???</p>',
#     'id': '4145769645',
#     'createdAt': '2018-10-15T12:48:09',
#     'author': {'username': 'mrideal247',
#      'about': '',
#      'name': 'MrCENTRIST247-The Centrist AF!',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-02-10T21:17:30',
#      'profileUrl': 'https://disqus.com/by/mrideal247/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '94325370',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/mrideal247.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/9432/5370/avatar32.jpg?1508960167'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/mrideal247.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/9432/5370/avatar92.jpg?1508960167',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/mrideal247.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/9432/5370/avatar92.jpg?1508960167'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': 4145768916,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Why are Cons addicted to PROJECTION???',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 2,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:47:48',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 7,
#     'message': '<p>He’s probably referring to another foreign attack on our political process that he’s coordinating</p>',
#     'id': '4145769149',
#     'createdAt': '2018-10-15T12:47:48',
#     'author': {'username': 'phan123',
#      'about': '',
#      'name': 'Steve DeBerg',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-04-29T17:46:48',
#      'profileUrl': 'https://disqus.com/by/phan123/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '105110193',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/phan123.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/10511/193/avatar32.jpg?1436221377'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/phan123.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/10511/193/avatar92.jpg?1436221377',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/phan123.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/10511/193/avatar92.jpg?1436221377'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'He’s probably referring to another foreign attack on our political process that he’s coordinating',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 7,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:47:37',
#     'dislikes': 1,
#     'numReports': 0,
#     'likes': 1,
#     'message': '<p>Bring on the liberal hate. Nothing but absolute pure hatred to the core of their souls. They have completely lost their humanity.</p>',
#     'id': '4145768916',
#     'createdAt': '2018-10-15T12:47:37',
#     'author': {'username': 'mooookiestix',
#      'about': '',
#      'name': 'MooookieStix',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-09-28T12:48:24',
#      'profileUrl': 'https://disqus.com/by/mooookiestix/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '266564189',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/mooookiestix.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/26656/4189/avatar32.jpg?1506622053'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/mooookiestix.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/26656/4189/avatar92.jpg?1506622053',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/mooookiestix.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/26656/4189/avatar92.jpg?1506622053'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'Bring on the liberal hate. Nothing but absolute pure hatred to the core of their souls. They have completely lost their humanity.',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 0,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:47:22',
#     'dislikes': 0,
#     'numReports': 0,
#     'likes': 5,
#     'message': '<p>and yet in those rust belts states you won, the Democrats are up in the double digits.</p><p>Good luck winning re-election buddy</p>',
#     'id': '4145768586',
#     'createdAt': '2018-10-15T12:47:22',
#     'author': {'username': 'disqus_59PrUrHVI6',
#      'about': '',
#      'name': 'idkmybffjill',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2017-10-27T16:50:28',
#      'profileUrl': 'https://disqus.com/by/disqus_59PrUrHVI6/',
#      'url': '',
#      'location': '',
#      'isPrivate': False,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '269434744',
#      'avatar': {'small': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar32.jpg?1495822997'},
#       'large': {'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#        'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'},
#       'permalink': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997',
#       'cache': 'https://c.disquscdn.com/uploads/forums/121/2423/avatar92.jpg?1495822997'}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': 'and yet in those rust belts states you won, the Democrats are up in the double digits.\n\nGood luck winning re-election buddy',
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 5,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False},
#    {'editableUntil': '2018-10-22T12:46:43',
#     'dislikes': 1,
#     'numReports': 0,
#     'likes': 12,
#     'message': "<p>He's told lies to that affect many, many times.</p>",
#     'id': '4145767738',
#     'createdAt': '2018-10-15T12:46:43',
#     'author': {'username': 'das85',
#      'about': '',
#      'name': 'DAS',
#      'disable3rdPartyTrackers': False,
#      'isPowerContributor': False,
#      'joinedAt': '2014-10-10T22:07:02',
#      'profileUrl': 'https://disqus.com/by/das85/',
#      'url': '',
#      'location': '',
#      'isPrivate': True,
#      'signedUrl': '',
#      'isPrimary': True,
#      'isAnonymous': False,
#      'id': '125222788',
#      'avatar': {'small': {'permalink': 'https://disqus.com/api/users/avatars/das85.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/12522/2788/avatar32.jpg?1454537286'},
#       'isCustom': True,
#       'permalink': 'https://disqus.com/api/users/avatars/das85.jpg',
#       'cache': 'https://c.disquscdn.com/uploads/users/12522/2788/avatar92.jpg?1454537286',
#       'large': {'permalink': 'https://disqus.com/api/users/avatars/das85.jpg',
#        'cache': 'https://c.disquscdn.com/uploads/users/12522/2788/avatar92.jpg?1454537286'}}},
#     'media': [],
#     'isSpam': False,
#     'isDeletedByAuthor': False,
#     'isDeleted': False,
#     'parent': None,
#     'isApproved': True,
#     'isFlagged': False,
#     'raw_message': "He's told lies to that affect many, many times.",
#     'isHighlighted': False,
#     'canVote': False,
#     'thread': '6971761113',
#     'forum': 'thehill-v4',
#     'points': 11,
#     'moderationLabels': [],
#     'isEdited': False,
#     'sb': False}]}]
